# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# %%
books=pd.read_csv("hathi_ia_texts.csv")

# %%
import re

# %%
def clean(s):
    s=s.split(";")[0]
    s=re.sub('[^a-zA-Z ]+', '', s) #keep only alphabetical characters
    s=s.lower()
    
    s=s[:50]
    return s

# %%
books["title"]=books["title"].apply(clean)

# %%
books
# Out:
#      Unnamed: 0                       htid pub_place  \
# 0             0  coo1.ark:/13960/t2m623920       enk
# 1             1  coo1.ark:/13960/t58d0gk82       xx
# 2             2  coo1.ark:/13960/t6nz8rs9s       nyu
# 3             3         hvd.32044014467336       nyu
# 4             4         hvd.32044079736146       mau
# ..          ...                        ...       ...
# 136          92           cu31924031387602       NaN
# 139          95           cu31924031663002       NaN
# 140          97           cu31924031749827       NaN
# 141          98           cu31924031784832       NaN
# 143         100           cu31924032223806       NaN
#
#                                                  title  \
# 0    the elements of elocution with special referen...
# 1     the american star speaker and model elocutionist
# 2              the delsarte system of physical culture
# 3    the art of oratory system of delsarte from the...
# 4    lectures and practical lessons in the three de...
# ..                                                 ...
# 136                           the science of elocution
# 139  elocution the sources and elements of its powe...
# 140                kings college lectures on elocution
# 141                essays and postscripts on elocution
# 143                     elocution and the dramatic art
#
#                                         author  rights_date_used  \
# 0                            Clegg, Charles E.              1890
# 1            Brown, Charles Walter, 1866-1934.              1902
# 2                            Georgen, Eleanor.              1893
# 3                           Delaumosne, Abb'e.              1884
# 4                     Zachos, J. C. 1820-1898.              1870
# ..                                         ...               ...
# 136                               Hamill, S. S              1872
# 139  McIlvaine, J. H. (Joshua Hall), 1815-1897              1871
# 140          Plumptre, Charles John, 1818-1887              1881
# 141        Bell, Alexander Melville, 1819-1905              1886
# 143                          Smithson, David J              1897
#
#                                                   text
# 0    rgdetailscuthe elements of elocution with spec...
# 1    d physical culture elocution aiid delsarte bas...
# 2    t by the butterick publishing company limitedm...
# 3    iladelphiacsl echool of elooution and olatoryt...
# 4    meadville penn asnonresident professorbyfoohn ...
# ..                                                 ...
# 136  he united states on the use of the text httpww...
# 139  own copyright restrictions in the united state...
# 140  nited states on the use of the text httpwwwarc...
# 141  re no known copyright restrictions in the unit...
# 143  s book is in tine cornell university library t...
#
# [124 rows x 7 columns]

# %%
books=books.drop_duplicates(["title"])

# %%
books=books.dropna(subset=["text"])

# %%
books
# Out:
#      Unnamed: 0                       htid pub_place  \
# 0             0  coo1.ark:/13960/t2m623920       enk
# 1             1  coo1.ark:/13960/t58d0gk82       xx
# 2             2  coo1.ark:/13960/t6nz8rs9s       nyu
# 3             3         hvd.32044014467336       nyu
# 4             4         hvd.32044079736146       mau
# ..          ...                        ...       ...
# 136          92           cu31924031387602       NaN
# 139          95           cu31924031663002       NaN
# 140          97           cu31924031749827       NaN
# 141          98           cu31924031784832       NaN
# 143         100           cu31924032223806       NaN
#
#                                                  title  \
# 0    the elements of elocution with special referen...
# 1     the american star speaker and model elocutionist
# 2              the delsarte system of physical culture
# 3    the art of oratory system of delsarte from the...
# 4    lectures and practical lessons in the three de...
# ..                                                 ...
# 136                           the science of elocution
# 139  elocution the sources and elements of its powe...
# 140                kings college lectures on elocution
# 141                essays and postscripts on elocution
# 143                     elocution and the dramatic art
#
#                                         author  rights_date_used  \
# 0                            Clegg, Charles E.              1890
# 1            Brown, Charles Walter, 1866-1934.              1902
# 2                            Georgen, Eleanor.              1893
# 3                           Delaumosne, Abb'e.              1884
# 4                     Zachos, J. C. 1820-1898.              1870
# ..                                         ...               ...
# 136                               Hamill, S. S              1872
# 139  McIlvaine, J. H. (Joshua Hall), 1815-1897              1871
# 140          Plumptre, Charles John, 1818-1887              1881
# 141        Bell, Alexander Melville, 1819-1905              1886
# 143                          Smithson, David J              1897
#
#                                                   text
# 0    rgdetailscuthe elements of elocution with spec...
# 1    d physical culture elocution aiid delsarte bas...
# 2    t by the butterick publishing company limitedm...
# 3    iladelphiacsl echool of elooution and olatoryt...
# 4    meadville penn asnonresident professorbyfoohn ...
# ..                                                 ...
# 136  he united states on the use of the text httpww...
# 139  own copyright restrictions in the united state...
# 140  nited states on the use of the text httpwwwarc...
# 141  re no known copyright restrictions in the unit...
# 143  s book is in tine cornell university library t...
#
# [124 rows x 7 columns]

# %%
text = books['text']
model = CountVectorizer(ngram_range = (5, 5))
matrix = model.fit_transform(text).toarray()
df_output = pd.DataFrame(data = matrix, columns = model.get_feature_names_out())
df_output.T.tail(5)
# Out:
#                                 0    1    2    3    4    5    6    7    8    \
# zzzazim rfl pg xt spirus          0    0    0    0    0    0    0    0    0
# zzzi fi through their months      0    0    0    0    0    0    0    0    0
# zzziv by nebos lonely mountain    0    0    0    0    0    0    0    0    0
# zzzzi swell as agent ardent       0    0    0    0    0    0    0    0    0
# zzzzzz monster of iron steel      0    1    0    0    0    0    0    0    0
#
#                                 9    ...  114  115  116  117  118  119  120  \
# zzzazim rfl pg xt spirus          0  ...    0    0    0    0    0    0    0
# zzzi fi through their months      0  ...    0    0    0    0    0    0    0
# zzziv by nebos lonely mountain    0  ...    0    0    0    0    0    0    0
# zzzzi swell as agent ardent       0  ...    0    0    0    0    0    0    0
# zzzzzz monster of iron steel      0  ...    0    0    0    0    0    0    0
#
#                                 121  122  123
# zzzazim rfl pg xt spirus          0    0    0
# zzzi fi through their months      0    0    0
# zzziv by nebos lonely mountain    0    0    0
# zzzzi swell as agent ardent       0    0    0
# zzzzzz monster of iron steel      0    0    0
#
# [5 rows x 124 columns]

# %%
df_output["title"]=books["title"]
df_output=df_output.set_index("title")
df_output=df_output.T

# %%
def floor(num):
    if num>0:
        return 1
    else:
        return 0

# %%
df_output=df_output.applymap(floor)

# %%
df_output["sum"]=df_output.sum(axis=1)

# %%
df_output=df_output[df_output["sum"]>5].sort_values("sum", ascending=False)

# %%
df_output=df_output.T

# %%
df_output["books"]=list(books["title"]).append("sum")
df_output=df_output.set_index("books").T

# %%
df_output.to_csv("all_counts.csv")

# %%
reuse=pd.read_csv("all_count_matrix.csv")

# %%
reuse=df_output

# %%
top=reuse.head(20000)

# %%
top = top.iloc[:,:-1]

# %%
top=top.T

# %%
top["books"]=list(books["title"])

# %%
top=top.set_index("books").T

# %%
top=top.drop(columns=["books"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[335], line 1
# ----> 1 top=top.drop(columns=["books"])
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['books'] not found in axis"

# %%
list(top.index)
# Out:
# ['and at the same time',
#  'at the end of the',
#  'is one of the most',
#  'on the part of the',
#  'in the middle of the',
#  'the action to the word',
#  'at the close of the',
#  'suit the action to the',
#  'of the organs of speech',
#  'the very torrent tempest and',
#  'the word to the action',
#  'nobler in the mind to',
#  'the weight of the body',
#  'at the head of the',
#  'the speech pray you as',
#  'the tones of the voice',
#  'the upper part of the',
#  'to the word the word',
#  'at the same time the',
#  'not the modesty of nature',
#  'that the dread of something',
#  'in the very torrent tempest',
#  'it is not to be',
#  'very torrent tempest and as',
#  'action to the word the',
#  'sleep of death what dreams',
#  'that sleep of death what',
#  'of death what dreams may',
#  'in that sleep of death',
#  'for in the very torrent',
#  'take arms against sea of',
#  'the green graves of your',
#  'in the midst of the',
#  'the word the word to',
#  'torrent tempest and as may',
#  'thou deep and dark blue',
#  'tis nobler in the mind',
#  'to take arms against sea',
#  'on the tongue but if',
#  'to the action with this',
#  'by sleep to say we',
#  'have shuffled off this mortal',
#  'makes calamity of so long',
#  'on thou deep and dark',
#  'thus the native hue of',
#  'deep and dark blue ocean',
#  'to the end of the',
#  'word the word to the',
#  'this regard their currents turn',
#  'brought many captives home to',
#  'who would bear the whips',
#  'at the beginning of the',
#  'you trippingly on the tongue',
#  'age and body of the',
#  'to the nature of the',
#  'speech pray you as pronounced',
#  'of your passion you must',
#  'pray you as pronounced it',
#  'yet brutus says he was',
#  'you as pronounced it to',
#  'you must acquire and beget',
#  'air too much with your',
#  'it is one of the',
#  'action with this special observance',
#  'bear the whips and scorns',
#  'the dread of something after',
#  'the mirror up to nature',
#  'of the voice in the',
#  'did see that on the',
#  'on the face of the',
#  'hath brought many captives home',
#  'it will be found that',
#  'the tongue but if you',
#  'in the face of the',
#  'passion you must acquire and',
#  'droppeth as the gentle rain',
#  'with this special observance that',
#  'this secret dread and inward',
#  'for the most part are',
#  'would bear the whips and',
#  'as well as in the',
#  'to split the ears of',
#  'whence this secret dread and',
#  'responsive voice was heard at',
#  'very age and body of',
#  'the very age and body',
#  'we have shuffled off this',
#  'thou hope with eyes so',
#  'be or not to be',
#  'quality of mercy is not',
#  'by the side of the',
#  'word to the action with',
#  'that may give it smoothness',
#  'the air too much with',
#  'mightiest in the mightiest it',
#  'insolence of office and the',
#  'to be that is the',
#  'oppressors wrong the proud mans',
#  'the action with this special',
#  'that men do lives after',
#  'under leave of brutus and',
#  'and the very age and',
#  'does make cowards of us',
#  'this special observance that you',
#  'leave of brutus and the',
#  'the lovely scenes at distance',
#  'bade the lovely scenes at',
#  'as the gentle rain from',
#  'tatters to very rags to',
#  'and arrows of outrageous fortune',
#  'place beneath it is twice',
#  'long farewell to all my',
#  'as pronounced it to you',
#  'conscience does make cowards of',
#  'the place beneath it is',
#  'for the green graves of',
#  'it were so it was',
#  'the whips and scorns of',
#  'that gives and him that',
#  'saw the air too much',
#  'but if you mouth it',
#  'there is all nature cries',
#  'the rocks the woods the',
#  'with the pale cast of',
#  'you mouth it as many',
#  'to show virtue her own',
#  'patient merit of the unworthy',
#  'he thinks good easy man',
#  'evil that men do lives',
#  'it will be observed that',
#  'to you trippingly on the',
#  'can lend three thousand ducats',
#  'to others that we know',
#  'the pole or in the',
#  'sicklied oer with the pale',
#  'mouth it as many of',
#  'him that gives and him',
#  'oerstep not the modesty of',
#  'have done this deed are',
#  'others that we know not',
#  'pole or in the torrid',
#  'to tatters to very rags',
#  'not saw the air too',
#  'where her sweetest theme she',
#  'pardon me do not mean',
#  'do had as lief the',
#  'if you mouth it as',
#  'me do not mean to',
#  'the roof of the mouth',
#  'tutor suit the action to',
#  'from the rocks the woods',
#  'turns they felt the glowing',
#  'soft responsive voice was heard',
#  'they would go and kiss',
#  'farewell to all my greatness',
#  'all did see that on',
#  'in the use of the',
#  'split the ears of the',
#  'were so it was grievous',
#  'fly to others that we',
#  'green graves of your sires',
#  'thinks good easy man full',
#  'more and by sleep to',
#  'tempest and as may say',
#  'car rattling oer the stony',
#  'chase the glowing hours with',
#  'the soul to hear robustious',
#  'do not saw the air',
#  'that there is all nature',
#  'and by sleep to say',
#  'in the mind of the',
#  'is oft interred with their',
#  'that have done this deed',
#  'me to the soul to',
#  'with the dance let joy',
#  'when he thinks good easy',
#  'her own feature scorn her',
#  'the most part are capable',
#  'monsters of the deep are',
#  'and as may say whirlwind',
#  'in such manner as to',
#  'virtue her own feature scorn',
#  'not to be that is',
#  'the deep are made each',
#  'is the state of man',
#  'of the deep are made',
#  'most part are capable of',
#  'to the soul to hear',
#  'the car rattling oer the',
#  'thousand fleets sweep over thee',
#  'lose the name of action',
#  'must pause till it come',
#  'fleets sweep over thee in',
#  'voice was heard at every',
#  'ready gods with all your',
#  'as may say whirlwind of',
#  'the dance let joy be',
#  'tongue but if you mouth',
#  'till it come back to',
#  'passions oft to hear her',
#  'dim with age and nature',
#  'all do know this mantle',
#  'if the clouds its echo',
#  'image and the very age',
#  'they come the greek the',
#  'of man today he puts',
#  'rude clash he struck the',
#  'friends sweet friends let me',
#  'till the last armed foe',
#  'or not to be that',
#  'of outrageous fortune or to',
#  'to nature to show virtue',
#  'enterprises of great pith and',
#  'thou art fled to brutish',
#  'is in the coffin there',
#  'gently for in the very',
#  'part are capable of nothing',
#  'the glowing hours with flying',
#  'cur can lend three thousand',
#  'oer with the pale cast',
#  'arms they come the greek',
#  'and dark blue ocean roll',
#  'know me all plain blunt',
#  'were her tresses seen her',
#  'he himself might his quietus',
#  'at the same time to',
#  'are capable of nothing but',
#  'sea of troubles and by',
#  'of troubles and by opposing',
#  'say to you should not',
#  'whirlwind of your passion you',
#  'own image and the very',
#  'at the end of sentence',
#  'private griefs they have alas',
#  'players do had as lief',
#  'rags to split the ears',
#  'old with service to the',
#  'whether tis nobler in the',
#  'it is it is the',
#  'the ears of the groundlings',
#  'you oerstep not the modesty',
#  'dip their napkins in his',
#  'the modesty of nature for',
#  'the quality of mercy is',
#  'many summers in sea of',
#  'dying mention it within their',
#  'would go and kiss dead',
#  'it to you trippingly on',
#  'the depths and shoals of',
#  'or in the torrid clime',
#  'in the coffin there with',
#  'he did thrice refuse was',
#  'speak the speech pray you',
#  'her own image and the',
#  'nature to show virtue her',
#  'your passion you must acquire',
#  'and old with service to',
#  'would her touch the strain',
#  'and lose the name of',
#  'that which he delights in',
#  'the clouds its echo would',
#  'griefs they have alas know',
#  'soon he saw the brisk',
#  'own feature scorn her own',
#  'thousand hearts beat happily and',
#  'slings and arrows of outrageous',
#  'arrows of outrageous fortune or',
#  'do brutus wrong and cassius',
#  'if any speak for him',
#  'for your altars and your',
#  'observe you must stand and',
#  'wrong the dead to wrong',
#  'for him as he was',
#  'heart is in the coffin',
#  'temperance that may give it',
#  'the last armed foe expires',
#  'heavy sound breaks in once',
#  'age and nature sink in',
#  'beg hair of him for',
#  'he delights in must be',
#  'hearts and minds to mutiny',
#  'their napkins in his sacred',
#  'am to speak what do',
#  'on echo still through all',
#  'ransoms did the general coffers',
#  'very rags to split the',
#  'have done that you should',
#  'trippingly on the tongue but',
#  'sweet friends let me not',
#  'what fall was there my',
#  'heartache and the thousand natural',
#  'so are they all all',
#  'the monsters of the deep',
#  'all the depths and shoals',
#  'the state of man today',
#  'imitate the action of the',
#  'far beyond my depth my',
#  'what weep you when you',
#  'all gently for in the',
#  'who for the most part',
#  'your altars and your fires',
#  'the first part of the',
#  'as well as to the',
#  'that you oerstep not the',
#  'weep you when you but',
#  'speak for him have offended',
#  'shows the force of temporal',
#  'was my friend faithful and',
#  'here am to speak what',
#  'the drawn dagger and defies',
#  'at the base of pompeys',
#  'and antidote are both before',
#  'state of man today he',
#  'her tresses seen her zone',
#  'show virtue her own feature',
#  'made them do it they',
#  'with age and nature sink',
#  'the divinity that stirs within',
#  'your tutor suit the action',
#  'any speak for him have',
#  'it will be seen that',
#  'of the voice and the',
#  'care should be taken to',
#  'as they oft had heard',
#  'should be given to the',
#  'the face of the earth',
#  'beget temperance that may give',
#  'drawn dagger and defies its',
#  'you know me all plain',
#  'the dread and fear of',
#  'in breeze or gale or',
#  'or storm icing the pole',
#  'not too tame neither but',
#  'the tip of the tongue',
#  'for his love joy for',
#  'arm it is it is',
#  'and thus the native hue',
#  'and they would go and',
#  'the praise of their own',
#  'in dull cold marble where',
#  'makes us rather bear those',
#  'dull cold marble where no',
#  'he was ambitious and brutus',
#  'all and thus the native',
#  'of us all and thus',
#  'with this regard their currents',
#  'acquire and beget temperance that',
#  'against sea of troubles and',
#  'neither wit nor words nor',
#  'them do it they are',
#  'today he puts forth the',
#  'the while ran blood great',
#  'in the name of the',
#  'pause till it come back',
#  'in this place ran cassius',
#  'and body of the time',
#  'up to nature to show',
#  'and minds to mutiny and',
#  'third day comes frost killing',
#  'bane and antidote are both',
#  'in the case of the',
#  'to the mercy of the',
#  'breeze or gale or storm',
#  'storm icing the pole or',
#  'of brutus and the rest',
#  'to die to sleep to',
#  'read and they would go',
#  'rather bear those ills we',
#  'and sweat under weary life',
#  'so let it be with',
#  'farewell long farewell to all',
#  'all the while ran blood',
#  'be ready gods with all',
#  'power doth then show likest',
#  'and by opposing end them',
#  'us rather bear those ills',
#  'must acquire and beget temperance',
#  'ten thousand fleets sweep over',
#  'as you know me all',
#  'hate him for he is',
#  'is an attribute to god',
#  'mean to read and they',
#  'for moment like drop of',
#  'in the same manner as',
#  'by opposing end them to',
#  'did love him once not',
#  'one rude clash he struck',
#  'strike for your altars and',
#  'strike for the green graves',
#  'troubles and by opposing end',
#  'to very rags to split',
#  'and beget temperance that may',
#  'is enthroned in the hearts',
#  'at it as he was',
#  'in the silence of the',
#  'the pitch of the voice',
#  'sleep to say we end',
#  'earthly power doth then show',
#  'sounded all the depths and',
#  'judgment thou art fled to',
#  'should say to you should',
#  'arms against sea of troubles',
#  'that the poor have cried',
#  'or whence this secret dread',
#  'let me not stir you',
#  'sinks into thy depths with',
#  'all did love him once',
#  'mirror up to nature to',
#  'be dog and bay the',
#  'in the mind to suffer',
#  'was ambitious and brutus is',
#  'public leave to speak of',
#  'may come when we have',
#  'icing the pole or in',
#  'brutus says he was ambitious',
#  'to read and they would',
#  'weep for him as he',
#  'to be or not to',
#  'it as he was valiant',
#  'should do brutus wrong and',
#  'brutus antony there were an',
#  'or to take arms against',
#  'ambitious and brutus is an',
#  'done that you should be',
#  'us all and thus the',
#  'gods with all your thunderbolts',
#  'and truths then if thou',
#  'friends let me not stir',
#  'which he delights in must',
#  'at the praise of their',
#  'should be made of sterner',
#  'me public leave to speak',
#  'and from the rocks the',
#  'this overdone or come tardy',
#  'awry and lose the name',
#  'enthroned in the hearts of',
#  'the back part of the',
#  'if it were so it',
#  'do it they are wise',
#  'in moment brings me to',
#  'pronounced it to you trippingly',
#  'it is the cannons opening',
#  'feature scorn her own image',
#  'my heart is in the',
#  'of pity these are gracious',
#  'here so base that would',
#  'his if then that friend',
#  'flesh is heir to tis',
#  'shall digest the venom of',
#  'world of merriment their melody',
#  'of the muscles of the',
#  'gale or storm icing the',
#  'our eyes and thus far',
#  'when am forgotten as shall',
#  'good is oft interred with',
#  'much trash as may be',
#  'it appear so make your',
#  'the native hue of resolution',
#  'little wanton boys that swim',
#  'and lovers hear me for',
#  'dreams may come when we',
#  'make cowards of us all',
#  'is not to the strong',
#  'when that the poor have',
#  'thou glorious mirror where the',
#  'and the thousand natural shocks',
#  'tears for his love joy',
#  'but use all gently for',
#  'the breach dear friends once',
#  'bid them speak for me',
#  'there be players that have',
#  'too tame neither but let',
#  'souls what weep you when',
#  'so overdone is from the',
#  'eyes and thus far hear',
#  'man of such feeble temper',
#  'when we have shuffled off',
#  'will be found in the',
#  'come the greek the greek',
#  'by the action of the',
#  'he puts forth the tender',
#  'still he kept his wild',
#  'and all of us fell',
#  'it offends me to the',
#  'not mean to read and',
#  'the mellow horn her pensive',
#  'gathering tears and tremblings of',
#  'tell you that which you',
#  'the manner in which the',
#  'man today he puts forth',
#  'this is the state of',
#  'silent that you may hear',
#  'doth sit the dread and',
#  'digest the venom of your',
#  'forth the tender leaves of',
#  'is from the purpose of',
#  'up your spirits and put',
#  'dry our eyes and thus',
#  'end them to die to',
#  'hope with eyes so fair',
#  'sleep in dull cold marble',
#  'you have done that you',
#  'but that the dread of',
#  'him but as he was',
#  'sceptre shows the force of',
#  'till morn when youth and',
#  'neither but let your own',
#  'into thy depths with bubbling',
#  'men have lost their reason',
#  'to die midst flame and',
#  'love him once not without',
#  'oft interred with their bones',
#  'sleep till morn when youth',
#  'roll on thou deep and',
#  'come not friends to steal',
#  'neer prophetic sounds so full',
#  'then he falls as do',
#  'deep are made each zone',
#  'says he was ambitious and',
#  'themes the veering song was',
#  'puts forth the tender leaves',
#  'throned monarch better than his',
#  'sweep over thee in vain',
#  'heard others praise and that',
#  'marks the earth with ruin',
#  'was sound of revelry by',
#  'trash as may be grasped',
#  'none so poor to do',
#  'friend faithful and just to',
#  'the evil that men do',
#  'more unto the breach dear',
#  'wanton boys that swim on',
#  'shone oer fair women and',
#  'sleep to sleep perchance to',
#  'neither having the accent of',
#  'or gale or storm icing',
#  'to say we end the',
#  'it they are wise and',
#  'use all gently for in',
#  'appealing to the mercy of',
#  'he hath brought many captives',
#  'scorn her own image and',
#  'cowards of us all and',
#  'did thrice refuse was this',
#  'blesseth him that gives and',
#  'for in that sleep of',
#  'stood against the world now',
#  'be that is the question',
#  'prophetic sounds so full of',
#  'observance that you oerstep not',
#  'get the start of the',
#  'made men and not made',
#  'graves of your sires god',
#  'the melancholy menace of their',
#  'with all your thunderbolts dash',
#  'the throne of the invisible',
#  'now you weep and perceive',
#  'beauty and her chivalry and',
#  'rejoice at it as he',
#  'all your thunderbolts dash him',
#  'friend and that they know',
#  'woke to die midst flame',
#  'the wrecks are all thy',
#  'speak not to disprove what',
#  'not friends to steal away',
#  'outrageous fortune or to take',
#  'here under leave of brutus',
#  'which he did thrice refuse',
#  'who wraps the drapery of',
#  'man marks the earth with',
#  'tame neither but let your',
#  'to be found in the',
#  'strike till the last armed',
#  'all her works he must',
#  'am no orator as brutus',
#  'notes by distance made more',
#  'whence this pleasing hope this',
#  'her sweetest theme she chose',
#  'under me and now has',
#  'with eyes so fair what',
#  'friends to steal away your',
#  'special observance that you oerstep',
#  'my friend faithful and just',
#  'lamps shone oer fair women',
#  'foe expires strike for your',
#  'bear with me my heart',
#  'the mind to suffer the',
#  'not to disprove what brutus',
#  'out of his wreck to',
#  'one who wraps the drapery',
#  'the world now lies he',
#  'speak for me but were',
#  'lovely scenes at distance hail',
#  'her works he must delight',
#  'native hue of resolution is',
#  'do not mean to read',
#  'now this overdone or come',
#  'his love joy for his',
#  'clamorous appealing to the mercy',
#  'all my miseries but thou',
#  'die to sleep to sleep',
#  'ruffle up your spirits and',
#  'tale of terror now their',
#  'unto the breach dear friends',
#  'romans countrymen lend me your',
#  'have neither wit nor words',
#  'with me my heart is',
#  'by me as the idle',
#  'look in this place ran',
#  'him then burst his mighty',
#  'eyes so fair what was',
#  'lost their reason bear with',
#  'that heavy sound breaks in',
#  'invisible even from out thy',
#  'that have thought some of',
#  'you weep and perceive you',
#  'that you should be sorry',
#  'ends thou aimst at be',
#  'the saddle before her he',
#  'me and now has left',
#  'sit the dread and fear',
#  'them speak for me but',
#  'and bade the lovely scenes',
#  'of his wreck to rise',
#  'catch him once upon the',
#  'blew blast so loud and',
#  'and there was hurrying to',
#  'but let your own discretion',
#  'length broke under me and',
#  'morn when youth and pleasure',
#  'crown which he did thrice',
#  'and that they know full',
#  'and where her sweetest theme',
#  'this place ran cassius dagger',
#  'if then that friend demand',
#  'but the commons hear this',
#  'he sinks into thy depths',
#  'and dip their napkins in',
#  'me weep for him as',
#  'say whirlwind of your passion',
#  'an inspiring air that dale',
#  'to the saddle before her',
#  'of mans ravage save his',
#  'there was hurrying to and',
#  'gives and him that takes',
#  'dead to wrong myself and',
#  'you for from this day',
#  'inspiring air that dale and',
#  'glades and glooms the mingled',
#  'may say whirlwind of your',
#  'of people armed in the',
#  'shuffled off this mortal coil',
#  'you and all of us',
#  'so poor to do him',
#  'of office and the spurns',
#  'the sorrows of poor old',
#  'for who would bear the',
#  'hush hark deep sound strikes',
#  'and lies down to pleasant',
#  'that neither having the accent',
#  'offends me to the soul',
#  'yet in early greece she',
#  'then that friend demand why',
#  'let your own discretion be',
#  'was ambitious slew him there',
#  'eternity the throne of the',
#  'rocks the woods the vale',
#  'still would her touch the',
#  'glorious mirror where the almightys',
#  'more for that in low',
#  'and must pause till it',
#  'the dead to wrong myself',
#  'be silent that you may',
#  'is the cannons opening roar',
#  'god and your native land',
#  'works he must delight in',
#  'but thou hope with eyes',
#  'and ministers of grace defend',
#  'hark deep sound strikes like',
#  'me my heart is in',
#  'had made men and not',
#  'is it come to this',
#  'image of eternity the throne',
#  'gave me public leave to',
#  'me my bargains and my',
#  'broke under me and now',
#  'have lost their reason bear',
#  'rather be dog and bay',
#  'fortune or to take arms',
#  'so much trash as may',
#  'man so are they all',
#  'but brutus says he was',
#  'kingly crown which he did',
#  'parchment with the seal of',
#  'is it is the cannons',
#  'the image of eternity the',
#  'the invisible even from out',
#  'of eternity the throne of',
#  'had rather be dog and',
#  'of thought and enterprises of',
#  'to sleep perchance to dream',
#  'weary life but that the',
#  'from one to the other',
#  'he would the charming air',
#  'that which you yourselves do',
#  'wild his thoughts and gay',
#  'the ends thou aimst at',
#  'fall was there my countrymen',
#  'life but that the dread',
#  'for my mirth yea for',
#  'but as he was ambitious',
#  'love joy for his fortune',
#  'currents turn awry and lose',
#  'your fires strike for the',
#  'heard at every close and',
#  'act of congress in the',
#  'have so strutted and bellowed',
#  'to sleep to sleep perchance',
#  'it droppeth as the gentle',
#  'men do lives after them',
#  'not to the strong alone',
#  'expostulation with the deaf and',
#  'they felt the glowing mind',
#  'hands of peasants their vile',
#  'upon him the third day',
#  'way out of his wreck',
#  'dread of something after death',
#  'to the strong alone it',
#  'light to the saddle before',
#  'of the voice on the',
#  'he falls as do have',
#  'you for gold to pay',
#  'are all thy deed nor',
#  'heard with voice as trumpet',
#  'the breath and bend up',
#  'certain sums of gold which',
#  'the sinews summon up the',
#  'there where merchants most do',
#  'and not made them well',
#  'we know not of thus',
#  'not made them well they',
#  'merit of the unworthy takes',
#  'bones so let it be',
#  'that we know not of',
#  'be glad to learn of',
#  'and men have lost their',
#  'the swelling in the anger',
#  'this is one of the',
#  'to arms they come the',
#  'hard the breath and bend',
#  'close the wall up with',
#  'to the lively pipe his',
#  'see that on the lupercal',
#  'shadows clouds and darkness rest',
#  'in the direction of the',
#  'hue of resolution is sicklied',
#  'and shout and groan and',
#  'pleasure and bade the lovely',
#  'the side of the palefaced',
#  'one of the most important',
#  'body of the time his',
#  'did the general coffers fill',
#  'appear so make your vaunting',
#  'and moment with this regard',
#  'grave where is thy victory',
#  'how like fawning publican he',
#  'mad expostulation with the deaf',
#  'this pleasing hope this fond',
#  'the angels how can man',
#  'measures wan despair low sullen',
#  'come when we have shuffled',
#  'to all my greatness this',
#  'your sires god and your',
#  'laws delay the insolence of',
#  'the earth with ruin his',
#  'cause withholds you then to',
#  'your thunderbolts dash him to',
#  'expires strike for your altars',
#  'roll ten thousand fleets sweep',
#  'was there my countrymen then',
#  'blossoms and bears his blushing',
#  'shadow of mans ravage save',
#  'split you for from this',
#  'for the sake of the',
#  'cause and be silent that',
#  'you that which you yourselves',
#  'the strong alone it is',
#  'you then to mourn for',
#  'greek the greek he woke',
#  'have thought some of natures',
#  'others praise and that highly',
#  'respect not did send to',
#  'will it be when we',
#  'rude that would not be',
#  'of your sires god and',
#  'on herself and startles at',
#  'when for moment like drop',
#  'world of solemn thought their',
#  'to her hand and one',
#  'had as lief the towncrier',
#  'thy right hand carry gentle',
#  'pass by me as the',
#  'oer fair women and brave',
#  'slowly and sadly we laid',
#  'own discretion be your tutor',
#  'slime the monsters of the',
#  'ocean roll ten thousand fleets',
#  'the woods the vale she',
#  'saw in death his eyelids',
#  'his thoughts and gay of',
#  'all thy deed nor doth',
#  'against the world now lies',
#  'dint of pity these are',
#  'and one word in her',
#  'swiftly forming in the ranks',
#  'what rent the envious casca',
#  'that flesh is heir to',
#  'with their bones so let',
#  'wrecks are all thy deed',
#  'death what dreams may come',
#  'over thee in vain man',
#  'the will and makes us',
#  'swelling in the anger of',
#  'at the sound himself had',
#  'when he falls he falls',
#  'when he himself might his',
#  'their currents turn awry and',
#  'so base that would be',
#  'turn awry and lose the',
#  'ambition yet brutus says he',
#  'when thy summons comes to',
#  'so strutted and bellowed that',
#  'turk was dreaming of the',
#  'whose ransoms did the general',
#  'her hand and one word',
#  'and you and all of',
#  'air that dale and thicket',
#  'loved me weep for him',
#  'thee in vain man marks',
#  'immortality or whence this secret',
#  'when the blast of war',
#  'his maker hope to win',
#  'and write his speeches in',
#  'so fair what was thy',
#  'or come tardy off though',
#  'do lives after them the',
#  'must be so plato thou',
#  'for gold to pay my',
#  'takes when he himself might',
#  'of congress in the year',
#  'love to eyes which spake',
#  'their bones so let it',
#  'forming in the ranks of',
#  'my friend and that they',
#  'tender leaves of hope tomorrow',
#  'that friend demand why brutus',
#  'love the laws delay the',
#  'moment like drop of rain',
#  'can raise no money by',
#  'calamity of so long life',
#  'through the mellow horn her',
#  'hand and one word in',
#  'of natures journeymen had made',
#  'it is enthroned in the',
#  'opposing end them to die',
#  'which pardon me do not',
#  'the foremost man of all',
#  'sin fell the angels how',
#  'under weary life but that',
#  'there be any in this',
#  'dreams his song of triumph',
#  'be your tutor suit the',
#  'off this mortal coil must',
#  'it as many of our',
#  'people armed in the holy',
#  'do split you for from',
#  'the other side of the',
#  'the pale cast of thought',
#  'vain man marks the earth',
#  'that sin fell the angels',
#  'regard their currents turn awry',
#  'but make the judicious grieve',
#  'it as rich legacy unto',
#  'pith and moment with this',
#  'give us pause theres the',
#  'gods and truths then if',
#  'thou aimst at be thy',
#  'thunderbolts dash him to pieces',
#  'it do split you for',
#  'write his speeches in their',
#  'the insolence of office and',
#  'the greek he woke to',
#  'from the beginning to the',
#  'from out thy slime the',
#  'friend demand why brutus rose',
#  'the greek the greek he',
#  'in vain man marks the',
#  'and when he thinks good',
#  'touch to her hand and',
#  'sweat under weary life but',
#  'sweet aspect of princes and',
#  'what dreams may come when',
#  'can catch him once upon',
#  'fell the angels how can',
#  'less than his if then',
#  'of his maker hope to',
#  'countrymen and lovers hear me',
#  'if he would the charming',
#  'then and there was hurrying',
#  'fires strike for the green',
#  'sir is not to the',
#  'art fled to brutish beasts',
#  'eyes looked love to eyes',
#  'my mirth yea for my',
#  'stars shall fade away the',
#  'are gone over bank bush',
#  'him and write his speeches',
#  'not be roman if any',
#  'him and lies down to',
#  'in the anger of the',
#  'dog money is it possible',
#  'thy slime the monsters of',
#  'cold marble where no mention',
#  'the spurns that patient merit',
#  'and sleep in dull cold',
#  'not do them wrong rather',
#  'what world of merriment their',
#  'thy honest truth to play',
#  'chamber in the silent halls',
#  'shocks that flesh is heir',
#  'of terror now their turbulency',
#  'weary and old with service',
#  'delight in virtue and that',
#  'is no terror cassius in',
#  'fair lady he swung so',
#  'and all went merry as',
#  'of resolution is sicklied oer',
#  'of rain he sinks into',
#  'beyond my depth my highblown',
#  'and death for his ambition',
#  'there can be no doubt',
#  'was heard at every close',
#  'like brave men long and',
#  'dreams through camp and court',
#  'sinews summon up the blood',
#  'charge of the light brigade',
#  'charge thee fling away ambition',
#  'he swung so light to',
#  'sinking or the swelling in',
#  'and thus far hear me',
#  'shed tear in all my',
#  'he was ambitious slew him',
#  'is my answer not that',
#  'of the voice in reading',
#  'and the spurns that patient',
#  'this is my answer not',
#  'of the time his form',
#  'way and room to your',
#  'service to the mercy of',
#  'blow set the wild echoes',
#  'shall be glad to learn',
#  'shall fade away the sun',
#  'shall please me well for',
#  'we know or dream or',
#  'capable of nothing but inexplicable',
#  'this mortal coil must give',
#  'thick upon him the third',
#  'shall we gather strength by',
#  'of thy honest truth to',
#  'they pass by me as',
#  'and this man is now',
#  'and awake your senses that',
#  'oft to hear her shell',
#  'what brutus spoke but here',
#  'us sir that we are',
#  'longing after immortality or whence',
#  'so sweet as to be',
#  'in the silent halls of',
#  'dew blew an inspiring air',
#  'on the use of the',
#  'the winters cold as well',
#  'the wind or the car',
#  'on throne of royal state',
#  'song and where her sweetest',
#  'now was and is to',
#  'altars and your fires strike',
#  'in virtue and that which',
#  'in the holy cause of',
#  'and sounded all the depths',
#  'it be when we are',
#  'use of that which is',
#  'thy depths with bubbling groan',
#  'who is here so base',
#  'by turns they felt the',
#  'clouds and darkness rest upon',
#  'it come back to me',
#  'ambitious when that the poor',
#  'and your fires strike for',
#  'so light to the saddle',
#  'is the question whether tis',
#  ...]

# %%
top = top.astype(int).T

# %%
top=top.head(1000)

# %%
top
# Out:
# books                         the elements of elocution with special reference t  \
# and at the same time                                                          1
# at the end of the                                                             1
# is one of the most                                                            0
# on the part of the                                                            0
# in the middle of the                                                          0
# ...                                                                         ...
# it come back to me                                                            1
# ambitious when that the poor                                                  1
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         the american star speaker and model elocutionist  \
# and at the same time                                                         0
# at the end of the                                                            1
# is one of the most                                                           1
# on the part of the                                                           1
# in the middle of the                                                         1
# ...                                                                        ...
# it come back to me                                                           0
# ambitious when that the poor                                                 0
# and your fires strike for                                                    0
# so light to the saddle                                                       0
# is the question whether tis                                                  1
#
# books                         the delsarte system of physical culture  \
# and at the same time                                                1
# at the end of the                                                   1
# is one of the most                                                  1
# on the part of the                                                  1
# in the middle of the                                                0
# ...                                                               ...
# it come back to me                                                  0
# ambitious when that the poor                                        0
# and your fires strike for                                           0
# so light to the saddle                                              0
# is the question whether tis                                         0
#
# books                         the art of oratory system of delsarte from the fre  \
# and at the same time                                                          1
# at the end of the                                                             0
# is one of the most                                                            1
# on the part of the                                                            0
# in the middle of the                                                          0
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         lectures and practical lessons in the three depart  \
# and at the same time                                                          0
# at the end of the                                                             0
# is one of the most                                                            0
# on the part of the                                                            0
# in the middle of the                                                          0
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         elements of rhetoric  comprising the substance of   \
# and at the same time                                                          1
# at the end of the                                                             0
# is one of the most                                                            0
# on the part of the                                                            0
# in the middle of the                                                          0
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         reading and elocution theoretical and practical  \
# and at the same time                                                        0
# at the end of the                                                           0
# is one of the most                                                          0
# on the part of the                                                          0
# in the middle of the                                                        0
# ...                                                                       ...
# it come back to me                                                          0
# ambitious when that the poor                                                0
# and your fires strike for                                                   0
# so light to the saddle                                                      0
# is the question whether tis                                                 0
#
# books                         a practical manual of elocution  embracing voice a  \
# and at the same time                                                          1
# at the end of the                                                             1
# is one of the most                                                            1
# on the part of the                                                            1
# in the middle of the                                                          1
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         the art of elocution  from the simple articulation  \
# and at the same time                                                          1
# at the end of the                                                             0
# is one of the most                                                            1
# on the part of the                                                            0
# in the middle of the                                                          1
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         the art of elocution  ...  \
# and at the same time                             1  ...
# at the end of the                                0  ...
# is one of the most                               1  ...
# on the part of the                               0  ...
# in the middle of the                             1  ...
# ...                                            ...  ...
# it come back to me                               0  ...
# ambitious when that the poor                     0  ...
# and your fires strike for                        0  ...
# so light to the saddle                           0  ...
# is the question whether tis                      0  ...
#
# books                         a ten weeks course in elocution  \
# and at the same time                                        0
# at the end of the                                           1
# is one of the most                                          1
# on the part of the                                          0
# in the middle of the                                        1
# ...                                                       ...
# it come back to me                                          0
# ambitious when that the poor                                0
# and your fires strike for                                   1
# so light to the saddle                                      0
# is the question whether tis                                 0
#
# books                         the science and art of elocution  or how to read a  \
# and at the same time                                                          0
# at the end of the                                                             0
# is one of the most                                                            0
# on the part of the                                                            1
# in the middle of the                                                          1
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     1
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         the science and art of elocution embracing a compr  \
# and at the same time                                                          0
# at the end of the                                                             0
# is one of the most                                                            0
# on the part of the                                                            1
# in the middle of the                                                          1
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     1
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         elocution voice and gesture  \
# and at the same time                                    0
# at the end of the                                       1
# is one of the most                                      1
# on the part of the                                      1
# in the middle of the                                    0
# ...                                                   ...
# it come back to me                                      1
# ambitious when that the poor                            0
# and your fires strike for                               0
# so light to the saddle                                  0
# is the question whether tis                             0
#
# books                         elocution for advanced pupils  \
# and at the same time                                      1
# at the end of the                                         0
# is one of the most                                        0
# on the part of the                                        1
# in the middle of the                                      0
# ...                                                     ...
# it come back to me                                        0
# ambitious when that the poor                              0
# and your fires strike for                                 0
# so light to the saddle                                    0
# is the question whether tis                               0
#
# books                         the science of elocution  \
# and at the same time                                 1
# at the end of the                                    1
# is one of the most                                   1
# on the part of the                                   1
# in the middle of the                                 0
# ...                                                ...
# it come back to me                                   0
# ambitious when that the poor                         0
# and your fires strike for                            1
# so light to the saddle                               1
# is the question whether tis                          1
#
# books                         elocution the sources and elements of its power a   \
# and at the same time                                                          1
# at the end of the                                                             1
# is one of the most                                                            1
# on the part of the                                                            1
# in the middle of the                                                          1
# ...                                                                         ...
# it come back to me                                                            0
# ambitious when that the poor                                                  0
# and your fires strike for                                                     0
# so light to the saddle                                                        0
# is the question whether tis                                                   0
#
# books                         kings college lectures on elocution  \
# and at the same time                                            1
# at the end of the                                               1
# is one of the most                                              1
# on the part of the                                              1
# in the middle of the                                            1
# ...                                                           ...
# it come back to me                                              1
# ambitious when that the poor                                    0
# and your fires strike for                                       0
# so light to the saddle                                          0
# is the question whether tis                                     1
#
# books                         essays and postscripts on elocution  \
# and at the same time                                            1
# at the end of the                                               1
# is one of the most                                              1
# on the part of the                                              0
# in the middle of the                                            0
# ...                                                           ...
# it come back to me                                              0
# ambitious when that the poor                                    0
# and your fires strike for                                       0
# so light to the saddle                                          0
# is the question whether tis                                     0
#
# books                         elocution and the dramatic art
# and at the same time                                       1
# at the end of the                                          0
# is one of the most                                         1
# on the part of the                                         0
# in the middle of the                                       1
# ...                                                      ...
# it come back to me                                         1
# ambitious when that the poor                               1
# and your fires strike for                                  0
# so light to the saddle                                     1
# is the question whether tis                                1
#
# [1000 rows x 124 columns]

# %%
top=top.T

# %%
coocc = top.T.dot(top)

# %%
import seaborn as sns

# %%
coocc
# Out:
#                               and at the same time  at the end of the  \
# and at the same time                            66                 42
# at the end of the                               42                 65
# is one of the most                              45                 43
# on the part of the                              36                 37
# in the middle of the                            31                 31
# ...                                            ...                ...
# it come back to me                              19                 16
# ambitious when that the poor                    20                 14
# and your fires strike for                       18                 14
# so light to the saddle                          20                 20
# is the question whether tis                     13                 14
#
#                               is one of the most  on the part of the  \
# and at the same time                          45                  36
# at the end of the                             43                  37
# is one of the most                            63                  34
# on the part of the                            34                  56
# in the middle of the                          32                  22
# ...                                          ...                 ...
# it come back to me                            15                  12
# ambitious when that the poor                  16                  11
# and your fires strike for                     13                  12
# so light to the saddle                        16                  15
# is the question whether tis                   16                  15
#
#                               in the middle of the  the action to the word  \
# and at the same time                            31                      29
# at the end of the                               31                      26
# is one of the most                              32                      30
# on the part of the                              22                      23
# in the middle of the                            49                      19
# ...                                            ...                     ...
# it come back to me                               9                      16
# ambitious when that the poor                     9                      13
# and your fires strike for                       13                      16
# so light to the saddle                           9                      13
# is the question whether tis                     10                      17
#
#                               at the close of the  suit the action to the  \
# and at the same time                           39                      29
# at the end of the                              33                      25
# is one of the most                             29                      29
# on the part of the                             29                      22
# in the middle of the                           21                      19
# ...                                           ...                     ...
# it come back to me                             12                      16
# ambitious when that the poor                   12                      13
# and your fires strike for                      11                      16
# so light to the saddle                         12                      13
# is the question whether tis                     8                      17
#
#                               of the organs of speech  \
# and at the same time                               32
# at the end of the                                  29
# is one of the most                                 31
# on the part of the                                 22
# in the middle of the                               19
# ...                                               ...
# it come back to me                                  9
# ambitious when that the poor                        8
# and your fires strike for                          14
# so light to the saddle                             11
# is the question whether tis                        10
#
#                               the very torrent tempest and  ...  \
# and at the same time                                    30  ...
# at the end of the                                       19  ...
# is one of the most                                      25  ...
# on the part of the                                      18  ...
# in the middle of the                                    20  ...
# ...                                                    ...  ...
# it come back to me                                      17  ...
# ambitious when that the poor                            15  ...
# and your fires strike for                               16  ...
# so light to the saddle                                  11  ...
# is the question whether tis                             12  ...
#
#                               use of that which is  \
# and at the same time                            16
# at the end of the                               15
# is one of the most                              15
# on the part of the                              12
# in the middle of the                            12
# ...                                            ...
# it come back to me                              12
# ambitious when that the poor                    10
# and your fires strike for                        2
# so light to the saddle                           9
# is the question whether tis                      8
#
#                               thy depths with bubbling groan  \
# and at the same time                                      18
# at the end of the                                         16
# is one of the most                                        16
# on the part of the                                        11
# in the middle of the                                      11
# ...                                                      ...
# it come back to me                                        10
# ambitious when that the poor                               8
# and your fires strike for                                 13
# so light to the saddle                                    10
# is the question whether tis                                9
#
#                               who is here so base  by turns they felt the  \
# and at the same time                           21                      19
# at the end of the                              15                      14
# is one of the most                             17                      10
# on the part of the                             14                      11
# in the middle of the                           10                      11
# ...                                           ...                     ...
# it come back to me                             12                       9
# ambitious when that the poor                   16                      11
# and your fires strike for                      10                      11
# so light to the saddle                         11                      10
# is the question whether tis                     9                       3
#
#                               clouds and darkness rest upon  \
# and at the same time                                     19
# at the end of the                                        13
# is one of the most                                       19
# on the part of the                                        8
# in the middle of the                                     14
# ...                                                     ...
# it come back to me                                        9
# ambitious when that the poor                              9
# and your fires strike for                                10
# so light to the saddle                                    9
# is the question whether tis                               9
#
#                               it come back to me  \
# and at the same time                          19
# at the end of the                             16
# is one of the most                            15
# on the part of the                            12
# in the middle of the                           9
# ...                                          ...
# it come back to me                            24
# ambitious when that the poor                  17
# and your fires strike for                      5
# so light to the saddle                         9
# is the question whether tis                    9
#
#                               ambitious when that the poor  \
# and at the same time                                    20
# at the end of the                                       14
# is one of the most                                      16
# on the part of the                                      11
# in the middle of the                                     9
# ...                                                    ...
# it come back to me                                      17
# ambitious when that the poor                            24
# and your fires strike for                                5
# so light to the saddle                                  11
# is the question whether tis                              7
#
#                               and your fires strike for  \
# and at the same time                                 18
# at the end of the                                    14
# is one of the most                                   13
# on the part of the                                   12
# in the middle of the                                 13
# ...                                                 ...
# it come back to me                                    5
# ambitious when that the poor                          5
# and your fires strike for                            24
# so light to the saddle                                8
# is the question whether tis                           6
#
#                               so light to the saddle  \
# and at the same time                              20
# at the end of the                                 20
# is one of the most                                16
# on the part of the                                15
# in the middle of the                               9
# ...                                              ...
# it come back to me                                 9
# ambitious when that the poor                      11
# and your fires strike for                          8
# so light to the saddle                            24
# is the question whether tis                        9
#
#                               is the question whether tis
# and at the same time                                   13
# at the end of the                                      14
# is one of the most                                     16
# on the part of the                                     15
# in the middle of the                                   10
# ...                                                   ...
# it come back to me                                      9
# ambitious when that the poor                            7
# and your fires strike for                               6
# so light to the saddle                                  9
# is the question whether tis                            24
#
# [1000 rows x 1000 columns]

# %%
import numpy as np

# %%
labels = clust
lut = dict(zip(set(labels), sns.color_palette()))
row_colors = pd.DataFrame(labels)[0].map(lut)

# %%
clustermap=sns.clustermap(coocc.reset_index(drop=True),yticklabels=False, xticklabels=False, row_colors=row_colors)
handles = [Patch(facecolor=lut[name]) for name in lut]
plt.legend(handles, lut, title='Clusters',
           bbox_to_anchor=(1, 1), bbox_transform=plt.gcf().transFigure, loc='upper right')
# Out:
# C:\Users\lucia\miniconda3\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
labels = clustermap.ax_heatmap.yaxis.get_majorticklabels()

# %%
labels
# Out:
# [Text(1, 0.5, 'at the end of the'),
#  Text(1, 1.5, 'on the part of the'),
#  Text(1, 2.5, 'and at the same time'),
#  Text(1, 3.5, 'is one of the most'),
#  Text(1, 4.5, 'oerstep not the modesty of'),
#  Text(1, 5.5, 'you oerstep not the modesty'),
#  Text(1, 6.5, 'that you oerstep not the'),
#  Text(1, 7.5, 'whirlwind of your passion you'),
#  Text(1, 8.5, 'your passion you must acquire'),
#  Text(1, 9.5, 'and body of the time'),
#  Text(1, 10.5, 'not too tame neither but'),
#  Text(1, 11.5, 'too tame neither but let'),
#  Text(1, 12.5, 'this overdone or come tardy'),
#  Text(1, 13.5, 'is from the purpose of'),
#  Text(1, 14.5, 'feature scorn her own image'),
#  Text(1, 15.5, 'so overdone is from the'),
#  Text(1, 16.5, 'up to nature to show'),
#  Text(1, 17.5, 'mirror up to nature to'),
#  Text(1, 18.5, 'there be players that have'),
#  Text(1, 19.5, 'the ears of the groundlings'),
#  Text(1, 20.5, 'it offends me to the'),
#  Text(1, 21.5, 'as pronounced it to you'),
#  Text(1, 22.5, 'pray you as pronounced it'),
#  Text(1, 23.5, 'you as pronounced it to'),
#  Text(1, 24.5, 'do had as lief the'),
#  Text(1, 25.5, 'players do had as lief'),
#  Text(1, 26.5, 'tatters to very rags to'),
#  Text(1, 27.5, 'to tatters to very rags'),
#  Text(1, 28.5, 'who for the most part'),
#  Text(1, 29.5, 'gently for in the very'),
#  Text(1, 30.5, 'all gently for in the'),
#  Text(1, 31.5, 'but use all gently for'),
#  Text(1, 32.5, 'rags to split the ears'),
#  Text(1, 33.5, 'very rags to split the'),
#  Text(1, 34.5, 'to very rags to split'),
#  Text(1, 35.5, 'to split the ears of'),
#  Text(1, 36.5, 'split the ears of the'),
#  Text(1, 37.5, 'part are capable of nothing'),
#  Text(1, 38.5, 'are capable of nothing but'),
#  Text(1, 39.5, 'the most part are capable'),
#  Text(1, 40.5, 'most part are capable of'),
#  Text(1, 41.5, 'the soul to hear robustious'),
#  Text(1, 42.5, 'me to the soul to'),
#  Text(1, 43.5, 'to the soul to hear'),
#  Text(1, 44.5, 'tongue but if you mouth'),
#  Text(1, 45.5, 'but if you mouth it'),
#  Text(1, 46.5, 'if you mouth it as'),
#  Text(1, 47.5, 'saw the air too much'),
#  Text(1, 48.5, 'not saw the air too'),
#  Text(1, 49.5, 'do not saw the air'),
#  Text(1, 50.5, 'tempest and as may say'),
#  Text(1, 51.5, 'you mouth it as many'),
#  Text(1, 52.5, 'mouth it as many of'),
#  Text(1, 53.5, 'speech pray you as pronounced'),
#  Text(1, 54.5, 'on the tongue but if'),
#  Text(1, 55.5, 'the tongue but if you'),
#  Text(1, 56.5, 'air too much with your'),
#  Text(1, 57.5, 'the air too much with'),
#  Text(1, 58.5, 'age and body of the'),
#  Text(1, 59.5, 'and the very age and'),
#  Text(1, 60.5, 'very age and body of'),
#  Text(1, 61.5, 'the very age and body'),
#  Text(1, 62.5, 'the mirror up to nature'),
#  Text(1, 63.5, 'her own feature scorn her'),
#  Text(1, 64.5, 'virtue her own feature scorn'),
#  Text(1, 65.5, 'own feature scorn her own'),
#  Text(1, 66.5, 'show virtue her own feature'),
#  Text(1, 67.5, 'to show virtue her own'),
#  Text(1, 68.5, 'own image and the very'),
#  Text(1, 69.5, 'her own image and the'),
#  Text(1, 70.5, 'image and the very age'),
#  Text(1, 71.5, 'to nature to show virtue'),
#  Text(1, 72.5, 'nature to show virtue her'),
#  Text(1, 73.5, 'the modesty of nature for'),
#  Text(1, 74.5, 'tutor suit the action to'),
#  Text(1, 75.5, 'your tutor suit the action'),
#  Text(1, 76.5, 'and as may say whirlwind'),
#  Text(1, 77.5, 'as may say whirlwind of'),
#  Text(1, 78.5, 'of your passion you must'),
#  Text(1, 79.5, 'that may give it smoothness'),
#  Text(1, 80.5, 'you must acquire and beget'),
#  Text(1, 81.5, 'passion you must acquire and'),
#  Text(1, 82.5, 'the very torrent tempest and'),
#  Text(1, 83.5, 'for the most part are'),
#  Text(1, 84.5, 'the speech pray you as'),
#  Text(1, 85.5, 'for in the very torrent'),
#  Text(1, 86.5, 'in the very torrent tempest'),
#  Text(1, 87.5, 'very torrent tempest and as'),
#  Text(1, 88.5, 'torrent tempest and as may'),
#  Text(1, 89.5, 'the action to the word'),
#  Text(1, 90.5, 'suit the action to the'),
#  Text(1, 91.5, 'with this special observance that'),
#  Text(1, 92.5, 'this special observance that you'),
#  Text(1, 93.5, 'not the modesty of nature'),
#  Text(1, 94.5, 'to the action with this'),
#  Text(1, 95.5, 'action with this special observance'),
#  Text(1, 96.5, 'word to the action with'),
#  Text(1, 97.5, 'the action with this special'),
#  Text(1, 98.5, 'the word to the action'),
#  Text(1, 99.5, 'to the word the word'),
#  Text(1, 100.5, 'action to the word the'),
#  Text(1, 101.5, 'the word the word to'),
#  Text(1, 102.5, 'word the word to the'),
#  Text(1, 103.5, 'for your altars and your'),
#  Text(1, 104.5, 'your altars and your fires'),
#  Text(1, 105.5, 'strike for your altars and'),
#  Text(1, 106.5, 'strike for the green graves'),
#  Text(1, 107.5, 'till the last armed foe'),
#  Text(1, 108.5, 'the last armed foe expires'),
#  Text(1, 109.5, 'by the side of the'),
#  Text(1, 110.5, 'come the greek the greek'),
#  Text(1, 111.5, 'they come the greek the'),
#  Text(1, 112.5, 'arms they come the greek'),
#  Text(1, 113.5, 'the green graves of your'),
#  Text(1, 114.5, 'for the green graves of'),
#  Text(1, 115.5, 'green graves of your sires'),
#  Text(1, 116.5, 'hate him for he is'),
#  Text(1, 117.5, 'in the silence of the'),
#  Text(1, 118.5, 'to the mercy of the'),
#  Text(1, 119.5, 'world of merriment their melody'),
#  Text(1, 120.5, 'temperance that may give it'),
#  Text(1, 121.5, 'beget temperance that may give'),
#  Text(1, 122.5, 'and beget temperance that may'),
#  Text(1, 123.5, 'acquire and beget temperance that'),
#  Text(1, 124.5, 'must acquire and beget temperance'),
#  Text(1, 125.5, 'pronounced it to you trippingly'),
#  Text(1, 126.5, 'speak the speech pray you'),
#  Text(1, 127.5, 'you trippingly on the tongue'),
#  Text(1, 128.5, 'trippingly on the tongue but'),
#  Text(1, 129.5, 'to you trippingly on the'),
#  Text(1, 130.5, 'it to you trippingly on'),
#  Text(1, 131.5, 'will be found in the'),
#  Text(1, 132.5, 'in the mind of the'),
#  Text(1, 133.5, 'in the same manner as'),
#  Text(1, 134.5, 'it will be observed that'),
#  Text(1, 135.5, 'of the voice in the'),
#  Text(1, 136.5, 'the tip of the tongue'),
#  Text(1, 137.5, 'in the name of the'),
#  Text(1, 138.5, 'in the use of the'),
#  Text(1, 139.5, 'care should be taken to'),
#  Text(1, 140.5, 'of the muscles of the'),
#  Text(1, 141.5, 'at the same time to'),
#  Text(1, 142.5, 'the manner in which the'),
#  Text(1, 143.5, 'it will be found that'),
#  Text(1, 144.5, 'as well as in the'),
#  Text(1, 145.5, 'it will be seen that'),
#  Text(1, 146.5, 'of the voice and the'),
#  Text(1, 147.5, 'as well as to the'),
#  Text(1, 148.5, 'in the case of the'),
#  Text(1, 149.5, 'at the beginning of the'),
#  Text(1, 150.5, 'the first part of the'),
#  Text(1, 151.5, 'the back part of the'),
#  Text(1, 152.5, 'should be given to the'),
#  Text(1, 153.5, 'imitate the action of the'),
#  Text(1, 154.5, 'the breach dear friends once'),
#  Text(1, 155.5, 'to the nature of the'),
#  Text(1, 156.5, 'by the action of the'),
#  Text(1, 157.5, 'in such manner as to'),
#  Text(1, 158.5, 'the pitch of the voice'),
#  Text(1, 159.5, 'in the mind to suffer'),
#  Text(1, 160.5, 'and arrows of outrageous fortune'),
#  Text(1, 161.5, 'against sea of troubles and'),
#  Text(1, 162.5, 'or to take arms against'),
#  Text(1, 163.5, 'arms against sea of troubles'),
#  Text(1, 164.5, 'sea of troubles and by'),
#  Text(1, 165.5, 'of troubles and by opposing'),
#  Text(1, 166.5, 'and by opposing end them'),
#  Text(1, 167.5, 'troubles and by opposing end'),
#  Text(1, 168.5, 'of outrageous fortune or to'),
#  Text(1, 169.5, 'arrows of outrageous fortune or'),
#  Text(1, 170.5, 'with this regard their currents'),
#  Text(1, 171.5, 'lose the name of action'),
#  Text(1, 172.5, 'and lose the name of'),
#  Text(1, 173.5, 'make cowards of us all'),
#  Text(1, 174.5, 'of us all and thus'),
#  Text(1, 175.5, 'us all and thus the'),
#  Text(1, 176.5, 'all and thus the native'),
#  Text(1, 177.5, 'and sweat under weary life'),
#  Text(1, 178.5, 'by opposing end them to'),
#  Text(1, 179.5, 'end them to die to'),
#  Text(1, 180.5, 'and thus the native hue'),
#  Text(1, 181.5, 'the native hue of resolution'),
#  Text(1, 182.5, 'sleep to say we end'),
#  Text(1, 183.5, 'awry and lose the name'),
#  Text(1, 184.5, 'and the thousand natural shocks'),
#  Text(1, 185.5, 'to die to sleep to'),
#  Text(1, 186.5, 'when we have shuffled off'),
#  Text(1, 187.5, 'may come when we have'),
#  Text(1, 188.5, 'dreams may come when we'),
#  Text(1, 189.5, 'whether tis nobler in the'),
#  Text(1, 190.5, 'to be or not to'),
#  Text(1, 191.5, 'slings and arrows of outrageous'),
#  Text(1, 192.5, 'flesh is heir to tis'),
#  Text(1, 193.5, 'be or not to be'),
#  Text(1, 194.5, 'or not to be that'),
#  Text(1, 195.5, 'to be that is the'),
#  Text(1, 196.5, 'not to be that is'),
#  Text(1, 197.5, 'he himself might his quietus'),
#  Text(1, 198.5, 'heartache and the thousand natural'),
#  Text(1, 199.5, 'more and by sleep to'),
#  Text(1, 200.5, 'and by sleep to say'),
#  Text(1, 201.5, 'rather bear those ills we'),
#  Text(1, 202.5, 'makes us rather bear those'),
#  Text(1, 203.5, 'us rather bear those ills'),
#  Text(1, 204.5, 'have shuffled off this mortal'),
#  Text(1, 205.5, 'we have shuffled off this'),
#  Text(1, 206.5, 'bear the whips and scorns'),
#  Text(1, 207.5, 'sicklied oer with the pale'),
#  Text(1, 208.5, 'with the pale cast of'),
#  Text(1, 209.5, 'oer with the pale cast'),
#  Text(1, 210.5, 'who would bear the whips'),
#  Text(1, 211.5, 'would bear the whips and'),
#  Text(1, 212.5, 'the whips and scorns of'),
#  Text(1, 213.5, 'oppressors wrong the proud mans'),
#  Text(1, 214.5, 'insolence of office and the'),
#  Text(1, 215.5, 'patient merit of the unworthy'),
#  Text(1, 216.5, 'tis nobler in the mind'),
#  Text(1, 217.5, 'enterprises of great pith and'),
#  Text(1, 218.5, 'fly to others that we'),
#  Text(1, 219.5, 'to others that we know'),
#  Text(1, 220.5, 'others that we know not'),
#  Text(1, 221.5, 'does make cowards of us'),
#  Text(1, 222.5, 'conscience does make cowards of'),
#  Text(1, 223.5, 'in that sleep of death'),
#  Text(1, 224.5, 'of death what dreams may'),
#  Text(1, 225.5, 'sleep of death what dreams'),
#  Text(1, 226.5, 'that sleep of death what'),
#  Text(1, 227.5, 'take arms against sea of'),
#  Text(1, 228.5, 'to take arms against sea'),
#  Text(1, 229.5, 'by sleep to say we'),
#  Text(1, 230.5, 'thus the native hue of'),
#  Text(1, 231.5, 'this regard their currents turn'),
#  Text(1, 232.5, 'makes calamity of so long'),
#  Text(1, 233.5, 'the dread of something after'),
#  Text(1, 234.5, 'nobler in the mind to'),
#  Text(1, 235.5, 'that the dread of something'),
#  Text(1, 236.5, 'yet brutus says he was'),
#  Text(1, 237.5, 'did see that on the'),
#  Text(1, 238.5, 'were so it was grievous'),
#  Text(1, 239.5, 'that men do lives after'),
#  Text(1, 240.5, 'evil that men do lives'),
#  Text(1, 241.5, 'under leave of brutus and'),
#  Text(1, 242.5, 'leave of brutus and the'),
#  Text(1, 243.5, 'must pause till it come'),
#  Text(1, 244.5, 'it were so it was'),
#  Text(1, 245.5, 'brought many captives home to'),
#  Text(1, 246.5, 'hath brought many captives home'),
#  Text(1, 247.5, 'and they would go and'),
#  Text(1, 248.5, 'not mean to read and'),
#  Text(1, 249.5, 'to read and they would'),
#  Text(1, 250.5, 'read and they would go'),
#  Text(1, 251.5, 'mean to read and they'),
#  Text(1, 252.5, 'dying mention it within their'),
#  Text(1, 253.5, 'beg hair of him for'),
#  Text(1, 254.5, 'dip their napkins in his'),
#  Text(1, 255.5, 'their napkins in his sacred'),
#  Text(1, 256.5, 'would go and kiss dead'),
#  Text(1, 257.5, 'they would go and kiss'),
#  Text(1, 258.5, 'pardon me do not mean'),
#  Text(1, 259.5, 'me do not mean to'),
#  Text(1, 260.5, 'all did see that on'),
#  Text(1, 261.5, 'friends sweet friends let me'),
#  Text(1, 262.5, 'sweet friends let me not'),
#  Text(1, 263.5, 'let me not stir you'),
#  Text(1, 264.5, 'friends let me not stir'),
#  Text(1, 265.5, 'ransoms did the general coffers'),
#  Text(1, 266.5, 'and all of us fell'),
#  Text(1, 267.5, 'did love him once not'),
#  Text(1, 268.5, 'all did love him once'),
#  Text(1, 269.5, 'thou art fled to brutish'),
#  Text(1, 270.5, 'that the poor have cried'),
#  Text(1, 271.5, 'judgment thou art fled to'),
#  Text(1, 272.5, 'souls what weep you when'),
#  Text(1, 273.5, 'made them do it they'),
#  Text(1, 274.5, 'them do it they are'),
#  Text(1, 275.5, 'do it they are wise'),
#  Text(1, 276.5, 'is in the coffin there'),
#  Text(1, 277.5, 'in the coffin there with'),
#  Text(1, 278.5, 'heart is in the coffin'),
#  Text(1, 279.5, 'was my friend faithful and'),
#  Text(1, 280.5, 'all do know this mantle'),
#  Text(1, 281.5, 'at the base of pompeys'),
#  Text(1, 282.5, 'in this place ran cassius'),
#  Text(1, 283.5, 'what fall was there my'),
#  Text(1, 284.5, 'all the while ran blood'),
#  Text(1, 285.5, 'should be made of sterner'),
#  Text(1, 286.5, 'weep you when you but'),
#  Text(1, 287.5, 'what weep you when you'),
#  Text(1, 288.5, 'the while ran blood great'),
#  Text(1, 289.5, 'of pity these are gracious'),
#  Text(1, 290.5, 'and minds to mutiny and'),
#  Text(1, 291.5, 'do brutus wrong and cassius'),
#  Text(1, 292.5, 'should do brutus wrong and'),
#  Text(1, 293.5, 'know me all plain blunt'),
#  Text(1, 294.5, 'you know me all plain'),
#  Text(1, 295.5, 'as you know me all'),
#  Text(1, 296.5, 'brutus antony there were an'),
#  Text(1, 297.5, 'up your spirits and put'),
#  Text(1, 298.5, 'tell you that which you'),
#  Text(1, 299.5, 'neither wit nor words nor'),
#  Text(1, 300.5, 'bid them speak for me'),
#  Text(1, 301.5, 'public leave to speak of'),
#  Text(1, 302.5, 'me public leave to speak'),
#  Text(1, 303.5, 'wrong the dead to wrong'),
#  Text(1, 304.5, 'hearts and minds to mutiny'),
#  Text(1, 305.5, 'private griefs they have alas'),
#  Text(1, 306.5, 'griefs they have alas know'),
#  Text(1, 307.5, 'have done this deed are'),
#  Text(1, 308.5, 'that have done this deed'),
#  Text(1, 309.5, 'am to speak what do'),
#  Text(1, 310.5, 'here am to speak what'),
#  Text(1, 311.5, 'till it come back to'),
#  Text(1, 312.5, 'pause till it come back'),
#  Text(1, 313.5, 'is oft interred with their'),
#  Text(1, 314.5, 'he did thrice refuse was'),
#  Text(1, 315.5, 'brutus says he was ambitious'),
#  Text(1, 316.5, 'ambitious and brutus is an'),
#  Text(1, 317.5, 'he was ambitious and brutus'),
#  Text(1, 318.5, 'was ambitious and brutus is'),
#  Text(1, 319.5, 'when that the poor have'),
#  Text(1, 320.5, 'my heart is in the'),
#  Text(1, 321.5, 'so are they all all'),
#  Text(1, 322.5, 'of brutus and the rest'),
#  Text(1, 323.5, 'so let it be with'),
#  Text(1, 324.5, 'if it were so it'),
#  Text(1, 325.5, 'here so base that would'),
#  Text(1, 326.5, 'speak for him have offended'),
#  Text(1, 327.5, 'if any speak for him'),
#  Text(1, 328.5, 'any speak for him have'),
#  Text(1, 329.5, 'for his love joy for'),
#  Text(1, 330.5, 'tears for his love joy'),
#  Text(1, 331.5, 'and lovers hear me for'),
#  Text(1, 332.5, 'good is oft interred with'),
#  Text(1, 333.5, 'at it as he was'),
#  Text(1, 334.5, 'weep for him as he'),
#  Text(1, 335.5, 'for him as he was'),
#  Text(1, 336.5, 'it as he was valiant'),
#  Text(1, 337.5, 'his if then that friend'),
#  Text(1, 338.5, 'silent that you may hear'),
#  Text(1, 339.5, 'farewell long farewell to all'),
#  Text(1, 340.5, 'forth the tender leaves of'),
#  Text(1, 341.5, 'today he puts forth the'),
#  Text(1, 342.5, 'he puts forth the tender'),
#  Text(1, 343.5, 'man today he puts forth'),
#  Text(1, 344.5, 'and truths then if thou'),
#  Text(1, 345.5, 'when am forgotten as shall'),
#  Text(1, 346.5, 'the depths and shoals of'),
#  Text(1, 347.5, 'all the depths and shoals'),
#  Text(1, 348.5, 'sounded all the depths and'),
#  Text(1, 349.5, 'our eyes and thus far'),
#  Text(1, 350.5, 'dry our eyes and thus'),
#  Text(1, 351.5, 'eyes and thus far hear'),
#  Text(1, 352.5, 'in dull cold marble where'),
#  Text(1, 353.5, 'dull cold marble where no'),
#  Text(1, 354.5, 'this is the state of'),
#  Text(1, 355.5, 'little wanton boys that swim'),
#  Text(1, 356.5, 'third day comes frost killing'),
#  Text(1, 357.5, 'is the state of man'),
#  Text(1, 358.5, 'of man today he puts'),
#  Text(1, 359.5, 'the state of man today'),
#  Text(1, 360.5, 'state of man today he'),
#  Text(1, 361.5, 'he thinks good easy man'),
#  Text(1, 362.5, 'when he thinks good easy'),
#  Text(1, 363.5, 'old with service to the'),
#  Text(1, 364.5, 'and old with service to'),
#  Text(1, 365.5, 'far beyond my depth my'),
#  Text(1, 366.5, 'thinks good easy man full'),
#  Text(1, 367.5, 'many summers in sea of'),
#  Text(1, 368.5, 'long farewell to all my'),
#  Text(1, 369.5, 'farewell to all my greatness'),
#  Text(1, 370.5, 'that gives and him that'),
#  Text(1, 371.5, 'him that gives and him'),
#  Text(1, 372.5, 'mightiest in the mightiest it'),
#  Text(1, 373.5, 'quality of mercy is not'),
#  Text(1, 374.5, 'place beneath it is twice'),
#  Text(1, 375.5, 'the place beneath it is'),
#  Text(1, 376.5, 'droppeth as the gentle rain'),
#  Text(1, 377.5, 'as the gentle rain from'),
#  Text(1, 378.5, 'the quality of mercy is'),
#  Text(1, 379.5, 'is an attribute to god'),
#  Text(1, 380.5, 'the dread and fear of'),
#  Text(1, 381.5, 'doth sit the dread and'),
#  Text(1, 382.5, 'shows the force of temporal'),
#  Text(1, 383.5, 'power doth then show likest'),
#  Text(1, 384.5, 'earthly power doth then show'),
#  Text(1, 385.5, 'at the end of sentence'),
#  Text(1, 386.5, 'the face of the earth'),
#  Text(1, 387.5, 'is enthroned in the hearts'),
#  Text(1, 388.5, 'enthroned in the hearts of'),
#  Text(1, 389.5, 'can lend three thousand ducats'),
#  Text(1, 390.5, 'cur can lend three thousand'),
#  Text(1, 391.5, 'say to you should not'),
#  Text(1, 392.5, 'should say to you should'),
#  Text(1, 393.5, 'the divinity that stirs within'),
#  Text(1, 394.5, 'or whence this secret dread'),
#  Text(1, 395.5, 'this secret dread and inward'),
#  Text(1, 396.5, 'whence this secret dread and'),
#  Text(1, 397.5, 'dim with age and nature'),
#  Text(1, 398.5, 'age and nature sink in'),
#  Text(1, 399.5, 'with age and nature sink'),
#  Text(1, 400.5, 'and antidote are both before'),
#  Text(1, 401.5, 'bane and antidote are both'),
#  Text(1, 402.5, 'the drawn dagger and defies'),
#  Text(1, 403.5, 'drawn dagger and defies its'),
#  Text(1, 404.5, 'in moment brings me to'),
#  Text(1, 405.5, 'there is all nature cries'),
#  Text(1, 406.5, 'that there is all nature'),
#  Text(1, 407.5, 'he delights in must be'),
#  Text(1, 408.5, 'that which he delights in'),
#  Text(1, 409.5, 'which he delights in must'),
#  Text(1, 410.5, 'be ready gods with all'),
#  Text(1, 411.5, 'gods with all your thunderbolts'),
#  Text(1, 412.5, 'be dog and bay the'),
#  Text(1, 413.5, 'much trash as may be'),
#  Text(1, 414.5, 'ready gods with all your'),
#  Text(1, 415.5, 'have done that you should'),
#  Text(1, 416.5, 'done that you should be'),
#  Text(1, 417.5, 'man of such feeble temper'),
#  Text(1, 418.5, 'it appear so make your'),
#  Text(1, 419.5, 'observe you must stand and'),
#  Text(1, 420.5, 'shall digest the venom of'),
#  Text(1, 421.5, 'digest the venom of your'),
#  Text(1, 422.5, 'and from the rocks the'),
#  Text(1, 423.5, 'hope with eyes so fair'),
#  Text(1, 424.5, 'voice was heard at every'),
#  Text(1, 425.5, 'thou hope with eyes so'),
#  Text(1, 426.5, 'responsive voice was heard at'),
#  Text(1, 427.5, 'bade the lovely scenes at'),
#  Text(1, 428.5, 'would her touch the strain'),
#  Text(1, 429.5, 'soft responsive voice was heard'),
#  Text(1, 430.5, 'the lovely scenes at distance'),
#  Text(1, 431.5, 'the rocks the woods the'),
#  Text(1, 432.5, 'from the rocks the woods'),
#  Text(1, 433.5, 'as they oft had heard'),
#  Text(1, 434.5, 'turns they felt the glowing'),
#  Text(1, 435.5, 'passions oft to hear her'),
#  Text(1, 436.5, 'were her tresses seen her'),
#  Text(1, 437.5, 'soon he saw the brisk'),
#  Text(1, 438.5, 'her tresses seen her zone'),
#  Text(1, 439.5, 'rude clash he struck the'),
#  Text(1, 440.5, 'one rude clash he struck'),
#  Text(1, 441.5, 'still he kept his wild'),
#  Text(1, 442.5, 'the mellow horn her pensive'),
#  Text(1, 443.5, 'where her sweetest theme she'),
#  Text(1, 444.5, 'on echo still through all'),
#  Text(1, 445.5, 'on the face of the'),
#  Text(1, 446.5, 'in the midst of the'),
#  Text(1, 447.5, 'in the face of the'),
#  Text(1, 448.5, 'to the end of the'),
#  Text(1, 449.5, 'at the same time the'),
#  Text(1, 450.5, 'it is not to be'),
#  Text(1, 451.5, 'in the middle of the'),
#  Text(1, 452.5, 'at the close of the'),
#  Text(1, 453.5, 'the tones of the voice'),
#  Text(1, 454.5, 'arm it is it is'),
#  Text(1, 455.5, 'it is it is the'),
#  Text(1, 456.5, 'it is the cannons opening'),
#  Text(1, 457.5, 'thousand hearts beat happily and'),
#  Text(1, 458.5, 'gathering tears and tremblings of'),
#  Text(1, 459.5, 'the praise of their own'),
#  Text(1, 460.5, 'at the praise of their'),
#  Text(1, 461.5, 'heavy sound breaks in once'),
#  Text(1, 462.5, 'chase the glowing hours with'),
#  Text(1, 463.5, 'the glowing hours with flying'),
#  Text(1, 464.5, 'the clouds its echo would'),
#  Text(1, 465.5, 'if the clouds its echo'),
#  Text(1, 466.5, 'car rattling oer the stony'),
#  Text(1, 467.5, 'the car rattling oer the'),
#  Text(1, 468.5, 'with the dance let joy'),
#  Text(1, 469.5, 'the dance let joy be'),
#  Text(1, 470.5, 'at the head of the'),
#  Text(1, 471.5, 'on thou deep and dark'),
#  Text(1, 472.5, 'thou deep and dark blue'),
#  Text(1, 473.5, 'deep and dark blue ocean'),
#  Text(1, 474.5, 'and dark blue ocean roll'),
#  Text(1, 475.5, 'sinks into thy depths with'),
#  Text(1, 476.5, 'thou glorious mirror where the'),
#  Text(1, 477.5, 'is not to the strong'),
#  Text(1, 478.5, 'the monsters of the deep'),
#  Text(1, 479.5, 'the pole or in the'),
#  Text(1, 480.5, 'pole or in the torrid'),
#  Text(1, 481.5, 'monsters of the deep are'),
#  Text(1, 482.5, 'the deep are made each'),
#  Text(1, 483.5, 'of the deep are made'),
#  Text(1, 484.5, 'in breeze or gale or'),
#  Text(1, 485.5, 'breeze or gale or storm'),
#  Text(1, 486.5, 'or in the torrid clime'),
#  Text(1, 487.5, 'gale or storm icing the'),
#  Text(1, 488.5, 'icing the pole or in'),
#  Text(1, 489.5, 'or storm icing the pole'),
#  Text(1, 490.5, 'storm icing the pole or'),
#  Text(1, 491.5, 'thousand fleets sweep over thee'),
#  Text(1, 492.5, 'fleets sweep over thee in'),
#  Text(1, 493.5, 'ten thousand fleets sweep over'),
#  Text(1, 494.5, 'for moment like drop of'),
#  Text(1, 495.5, 'of the organs of speech'),
#  Text(1, 496.5, 'the weight of the body'),
#  Text(1, 497.5, 'the roof of the mouth'),
#  Text(1, 498.5, 'the upper part of the'),
#  Text(1, 499.5, 'it is one of the')]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

# %%
Z = linkage(coocc, 'average')

# %%
Z
# Out:
# array([[100.        , 104.        ,   0.        ,   2.        ],
#        [328.        , 378.        ,   0.        ,   2.        ],
#        [233.        , 261.        ,   0.        ,   2.        ],
#        ...,
#        [972.        , 995.        , 153.45724975, 369.        ],
#        [991.        , 996.        , 156.08568136, 496.        ],
#        [994.        , 997.        , 170.53638157, 500.        ]])

# %%
from scipy.spatial import distance
from scipy.cluster import hierarchy

# %%
row_linkage = hierarchy.linkage(
    distance.pdist(coocc), method='average')

# %%
row_linkage
# Out:
# array([[100.        , 104.        ,   0.        ,   2.        ],
#        [328.        , 378.        ,   0.        ,   2.        ],
#        [233.        , 261.        ,   0.        ,   2.        ],
#        ...,
#        [972.        , 995.        , 153.45724975, 369.        ],
#        [991.        , 996.        , 156.08568136, 496.        ],
#        [994.        , 997.        , 170.53638157, 500.        ]])

# %%
dn=dendrogram(row_linkage, labels=coocc.index)

# %%
from scipy.cluster.hierarchy import fcluster

# %%
Z = linkage(coocc, 'average')

# %%
clust=fcluster(Z, 15, criterion='maxclust')

# %%
clust
# Out:
# array([ 2,  1,  2,  1,  8,  3,  8,  3, 12,  3,  3, 13,  9, 12,  3,  8,  8,
#         3,  8,  3, 13,  3,  8,  3,  3, 13, 13, 13, 13,  3, 13,  9,  9,  3,
#         3, 12, 13, 13,  3,  3, 13, 13, 13, 12, 13, 12,  8,  3, 13, 14, 13,
#         5,  3,  3,  5,  3,  3,  3, 15,  3,  3,  3,  5,  3, 13, 13,  3,  5,
#        14,  9, 14,  5,  3,  9,  3,  7,  3,  8,  3, 13,  5,  3,  8,  6,  3,
#         3, 13,  6, 13,  7,  9,  3,  3,  3,  7, 13, 13, 13,  3, 14, 14,  3,
#        13,  3, 14,  6,  6,  7,  3, 13,  7, 14,  3, 13,  7,  9, 14, 13,  7,
#         3,  3,  8,  6, 13,  3,  3, 13, 14, 14,  8,  3,  7, 13, 12, 13,  3,
#         7,  3, 14, 13, 12,  3,  3,  6, 14,  3,  3, 14,  5,  3,  6,  6,  6,
#        14, 14, 14,  5,  3, 14, 13,  9, 14, 13,  3, 11, 11,  3,  3,  8, 13,
#         5, 14, 14,  3, 11, 14,  3,  3, 12,  3,  5,  3, 13, 12, 14, 12,  3,
#         3, 11, 12, 13, 14, 12,  6,  8,  3, 11,  3, 14,  6,  8, 14, 11,  3,
#        10, 14,  6, 14, 10, 13, 13,  3, 13, 14, 14,  3,  3, 11,  7, 13, 10,
#        12, 14,  6, 13,  5,  3, 13, 13,  7,  3,  3,  8, 14,  3,  3, 14, 13,
#        11,  3,  3, 14,  3,  7, 14, 14, 14,  3, 14, 12, 14, 14,  3,  3,  3,
#         3, 14,  6, 13,  8, 11, 14,  6,  3, 11, 13, 13, 14, 14, 10,  8, 14,
#        14, 14,  3, 10, 11,  8, 14,  8, 14, 14, 14,  6, 14,  3,  8,  3, 14,
#        14, 13, 14, 12, 14, 14,  5, 14, 14,  3,  3, 10,  5,  5,  3, 14, 14,
#         7, 14, 14,  8, 14,  8, 14,  6,  3, 14,  8,  8,  3, 14,  5,  5,  5,
#         6,  5,  8,  3,  8, 14,  7, 12, 12,  3,  5, 14, 11, 13, 14, 11, 14,
#        13, 14, 14, 13, 13, 13,  3, 13, 14, 14, 14, 14,  5, 14, 14,  3,  3,
#        14, 14,  8,  5,  5, 12, 12, 14, 13, 14, 13, 13, 14, 14, 14,  8,  7,
#        13, 13,  3, 12, 14,  5,  7, 14, 12,  5, 13, 14,  6, 10, 10, 13,  3,
#         3,  7, 14,  5,  5, 13,  7, 14, 14,  7, 13, 14,  8, 14, 12, 14,  3,
#         8, 13, 14, 14, 13, 12, 14, 14, 14, 13, 14, 14, 14, 13, 14,  8, 13,
#         8, 14, 14,  8, 11, 14, 14,  6,  3, 13,  7,  5, 14, 14,  8,  3, 11,
#         3, 14, 14, 14, 14, 13,  8,  5,  5, 12, 14, 14, 14,  8,  8, 13, 14,
#        14, 13, 13, 12, 14, 12, 13, 14,  3,  5, 14,  3,  3, 14,  3, 14,  7,
#        13,  5, 10,  5, 14,  6, 14,  3, 14,  6, 11, 14,  5, 14, 14, 14,  7,
#         8, 14,  3, 14, 14, 13,  6, 14,  8, 13, 14,  7, 11,  3, 12, 14, 10,
#        14, 14, 11, 12, 14,  6, 14, 12, 14,  6, 14,  7, 12,  3, 12, 11,  8,
#        14, 14, 14,  5, 14, 11, 13,  3, 12, 13, 14,  3,  5, 14,  3, 13, 14,
#         7, 13, 14, 13,  6,  3,  7,  3, 10,  5,  8, 12, 14, 11, 14,  8, 14,
#        10, 12, 14, 14, 13, 14, 14,  5, 12,  3,  5, 10,  8, 14,  6,  8,  6,
#        14,  6, 14,  3, 14, 11, 10, 14, 13, 14, 14,  5, 14, 14,  6,  8, 13,
#        14,  3, 14,  5, 14, 13, 14,  5,  5, 14, 14, 14,  8, 14, 14,  6, 14,
#        11, 12,  3, 14,  8, 14,  8, 14,  7, 14,  6, 14,  5,  6, 11,  3, 14,
#        11, 14, 14,  6, 14, 14, 14, 12, 14, 14,  3,  6,  8, 12, 11,  7, 14,
#         8,  6,  6,  3, 12, 13, 14, 14, 13,  5, 13, 11,  5,  3,  3,  6, 14,
#         3, 14, 12,  6,  6, 12,  5, 14, 14, 14, 11, 10,  8,  6,  5, 11, 14,
#         3,  8, 12, 14,  5, 14, 14,  8, 13,  8, 14, 14, 14, 14, 11, 12, 12,
#        12,  8, 13, 13, 13,  4,  6, 14, 10, 14, 14, 13,  8, 14, 14, 13, 10,
#         6,  5,  3, 13,  7, 14, 12,  5,  6,  8, 14, 14, 13, 12,  8,  5, 14,
#         8, 12, 10,  5,  8,  5,  5,  3, 13,  3, 13, 14, 13,  8, 14,  5,  5,
#        10,  5,  5,  6, 14,  8,  5, 13, 10,  6,  5,  5,  3, 14,  8, 13,  5,
#         5,  5,  8, 14,  6, 13, 14, 10, 13, 12, 14,  8, 10, 12, 14, 14, 12,
#         8,  5, 14, 14, 12, 14, 10,  3,  3,  8, 12, 14, 10,  8, 12,  5,  8,
#         3, 14,  8, 11, 12,  3, 12, 12,  6, 10, 10, 12, 14, 14,  8, 11, 14,
#        13, 14, 12, 13, 12, 13,  5,  6, 14, 13, 13, 14, 13, 14,  5,  3, 10,
#        14,  8, 14,  6, 14, 12,  8,  5, 14,  7,  6,  3, 14,  8,  8, 13,  5,
#        11, 14, 11, 14, 14, 14, 13, 12,  8, 13,  6,  8,  3,  7, 13, 14,  8,
#        14, 13, 14, 10,  3, 13,  3, 12,  8,  5, 13, 12, 14, 13,  3, 14, 13,
#        13, 14, 14,  8,  8,  7, 13, 10,  4, 12, 14, 10, 12, 14,  8, 13, 14,
#        13,  5, 14, 14, 14, 14,  6, 11, 10, 12, 14, 11,  8,  8,  8,  7, 14,
#         5,  5,  5, 12, 14, 13, 14, 14,  5, 14,  5, 13,  5, 14,  8,  8,  8,
#        11, 13, 12, 14, 14,  4,  6, 10, 10,  5,  5, 14,  8,  5, 14, 14, 14,
#        14,  5, 13, 14,  3,  8, 14,  5,  8,  8,  8, 10,  3, 13, 14, 12, 14,
#         8,  5, 14,  6, 14, 12,  8, 12,  5,  6,  4,  7, 11,  5,  6,  3, 10,
#         8, 12, 14, 12,  7, 12, 14,  6,  8, 14, 14, 10,  8, 13],
#       dtype=int32)

# %%
clu3=np.where(clust == 7)[0]

# %%
list(coocc.iloc[clu3].index)
# Out:
# ['brought many captives home to',
#  'yet brutus says he was',
#  'did see that on the',
#  'hath brought many captives home',
#  'that men do lives after',
#  'under leave of brutus and',
#  'leave of brutus and the',
#  'long farewell to all my',
#  'it were so it was',
#  'he thinks good easy man',
#  'evil that men do lives',
#  'have done this deed are',
#  'pardon me do not mean',
#  'me do not mean to',
#  'they would go and kiss',
#  'farewell to all my greatness',
#  'all did see that on',
#  'were so it was grievous',
#  'thinks good easy man full',
#  'is oft interred with their',
#  'that have done this deed',
#  'when he thinks good easy',
#  'is the state of man',
#  'must pause till it come',
#  'till it come back to',
#  'all do know this mantle',
#  'of man today he puts',
#  'friends sweet friends let me',
#  'thou art fled to brutish',
#  'is in the coffin there',
#  'know me all plain blunt',
#  'private griefs they have alas',
#  'old with service to the',
#  'dip their napkins in his',
#  'many summers in sea of',
#  'dying mention it within their',
#  'would go and kiss dead',
#  'the depths and shoals of',
#  'in the coffin there with',
#  'he did thrice refuse was',
#  'and old with service to',
#  'griefs they have alas know',
#  'do brutus wrong and cassius',
#  'if any speak for him',
#  'wrong the dead to wrong',
#  'for him as he was',
#  'heart is in the coffin',
#  'beg hair of him for',
#  'hearts and minds to mutiny',
#  'their napkins in his sacred',
#  'am to speak what do',
#  'ransoms did the general coffers',
#  'sweet friends let me not',
#  'what fall was there my',
#  'so are they all all',
#  'all the depths and shoals',
#  'the state of man today',
#  'far beyond my depth my',
#  'what weep you when you',
#  'weep you when you but',
#  'speak for him have offended',
#  'was my friend faithful and',
#  'here am to speak what',
#  'at the base of pompeys',
#  'state of man today he',
#  'made them do it they',
#  'any speak for him have',
#  'you know me all plain',
#  'for his love joy for',
#  'and they would go and',
#  'in dull cold marble where',
#  'dull cold marble where no',
#  'he was ambitious and brutus',
#  'neither wit nor words nor',
#  'them do it they are',
#  'today he puts forth the',
#  'the while ran blood great',
#  'pause till it come back',
#  'in this place ran cassius',
#  'and minds to mutiny and',
#  'third day comes frost killing',
#  'of brutus and the rest',
#  'read and they would go',
#  'so let it be with',
#  'farewell long farewell to all',
#  'all the while ran blood',
#  'as you know me all',
#  'mean to read and they',
#  'did love him once not',
#  'at it as he was',
#  'sounded all the depths and',
#  'judgment thou art fled to',
#  'that the poor have cried',
#  'let me not stir you',
#  'all did love him once',
#  'was ambitious and brutus is',
#  'public leave to speak of',
#  'brutus says he was ambitious',
#  'to read and they would',
#  'weep for him as he',
#  'it as he was valiant',
#  'should do brutus wrong and',
#  'brutus antony there were an',
#  'ambitious and brutus is an',
#  'and truths then if thou',
#  'friends let me not stir',
#  'should be made of sterner',
#  'me public leave to speak',
#  'if it were so it',
#  'do it they are wise',
#  'my heart is in the',
#  'of pity these are gracious',
#  'here so base that would',
#  'his if then that friend',
#  'our eyes and thus far',
#  'when am forgotten as shall',
#  'good is oft interred with',
#  'little wanton boys that swim',
#  'and lovers hear me for',
#  'when that the poor have',
#  'tears for his love joy',
#  'bid them speak for me',
#  'souls what weep you when',
#  'eyes and thus far hear',
#  'he puts forth the tender',
#  'and all of us fell',
#  'not mean to read and',
#  'tell you that which you',
#  'man today he puts forth',
#  'this is the state of',
#  'silent that you may hear',
#  'forth the tender leaves of',
#  'up your spirits and put',
#  'dry our eyes and thus']
